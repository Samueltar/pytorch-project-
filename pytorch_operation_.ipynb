# %%
#operations
import torch
import numpy as np

# %%
tensor_a = torch.tensor([1,2,3,4])
tensor_b = torch.tensor([5,6,7,8])

# %%
tensor_a + tensor_b
# Out:
# tensor([ 6,  8, 10, 12])

# %%
a=torch.add(tensor_a,tensor_b)
a
# Out:
# tensor([ 6,  8, 10, 12])

# %%
b=torch.sub(tensor_a,tensor_b)
b
# Out:
# tensor([-4, -4, -4, -4])

# %%
c=torch.mul(tensor_a,tensor_b)
c
# Out:
# tensor([ 5, 12, 21, 32])

# %%
d=torch.div(tensor_a,tensor_b)
d
# Out:
# tensor([0.2000, 0.3333, 0.4286, 0.5000])

# %%
tensor_b % tensor_a
# Out:
# tensor([0, 0, 1, 0])

# %%
torch.pow(tensor_a,tensor_b)
# Out:
# tensor([    1,    64,  2187, 65536])
